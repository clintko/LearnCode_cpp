// %%
#include <iostream>
std::cout << "some output" << std::endl;
// Out:
// In file included from input_line_1:1:
// In file included from /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/new:40:
// In file included from /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/exception:143:
// In file included from /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/bits/nested_exception.h:40:
// In file included from /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/bits/move.h:54:
// /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/type_traits:149:31: error: no member named 'value' in
//       'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /usr/lib/gcc/x86_64-linux-gnu/7.3.0/../../../../include/c++/7.3.0/ostream:676:24: note: in instantiation of template class
//       'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char>
// ...
